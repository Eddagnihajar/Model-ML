# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('train.csv',sep=',',decimal='.')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.describe() #pour les valeurs numeriques
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.describe(include='O')#les valeurs gategoriques
# Out:
#        MSZoning Street Alley LotShape LandContour Utilities LotConfig  \
# count      1460   1460    91     1460        1460      1460      1460
# unique        5      2     2        4           4         2         5
# top          RL   Pave  Grvl      Reg         Lvl    AllPub    Inside
# freq       1151   1454    50      925        1311      1459      1052
#
#        LandSlope Neighborhood Condition1  ... GarageType GarageFinish  \
# count       1460         1460       1460  ...       1379         1379
# unique         3           25          9  ...          6            3
# top          Gtl        NAmes       Norm  ...     Attchd          Unf
# freq        1382          225       1260  ...        870          605
#
#        GarageQual GarageCond PavedDrive PoolQC  Fence MiscFeature SaleType  \
# count        1379       1379       1460      7    281          54     1460
# unique          5          5          3      3      4           4        9
# ...

# %%
df.isnull().sum()/len(df)
# Out:
# Id               0.000000
# MSSubClass       0.000000
# MSZoning         0.000000
# LotFrontage      0.177397
# LotArea          0.000000
#                    ...
# MoSold           0.000000
# YrSold           0.000000
# SaleType         0.000000
# SaleCondition    0.000000
# SalePrice        0.000000
# Length: 81, dtype: float64

# %%
pd.DataFrame(df.isnull().sum()/len(df),columns=['ratio']).query('ratio>0').sort_values(by='ratio')
# Out:
#                  ratio
# Electrical    0.000685
# MasVnrType    0.005479
# MasVnrArea    0.005479
# BsmtQual      0.025342
# BsmtCond      0.025342
# BsmtFinType1  0.025342
# BsmtExposure  0.026027
# BsmtFinType2  0.026027
# GarageCond    0.055479
# GarageQual    0.055479
# GarageFinish  0.055479
# GarageType    0.055479
# GarageYrBlt   0.055479
# LotFrontage   0.177397
# FireplaceQu   0.472603
# Fence         0.807534
# Alley         0.937671
# MiscFeature   0.963014
# PoolQC        0.995205

# %%
pd.__version__
# Out:
# '1.3.4'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
sns.distplot(df.SalePrice)
# Out:
# C:\Users\exe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %%
df.SalePrice.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
def custom_error(y,y_pred):
    np.sqrt(np.mean(np.sum((np.log(y)-np.log(y_pred))^2)))
    return RMSE(log(y),log(y_pred))

# %%
df['log_SalePrice']=np.log(df['SalePrice'])

# %%
sns.distplot(df.log_SalePrice)
# Out:
# C:\Users\exe\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='log_SalePrice', ylabel='Density'>

# %%
import warnings
warnings.filterwarnings("ignore")
for col in df.columns:
    if df[col].dtype !='object':
        plt.figure(figsize=(12,8))
        sns.distplot(df[col])
        plt.show()

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
target= df['HouseStyle']

# %%
df['HouseStyle'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
df['HouseStyle'].describe()
# Out:
# count       1460
# unique         8
# top       1Story
# freq         726
# Name: HouseStyle, dtype: object

# %%
df['HouseStyle'].head()
# Out:
# 0    2Story
# 1    1Story
# 2    2Story
# 3    2Story
# 4    2Story
# Name: HouseStyle, dtype: object

# %%
df['HouseStyle'].value_counts()
# Out:
# 1Story    726
# 2Story    445
# 1.5Fin    154
# SLvl       65
# SFoyer     37
# 1.5Unf     14
# 2.5Unf     11
# 2.5Fin      8
# Name: HouseStyle, dtype: int64

# %%
df['BsmtFinType1'].value_counts().plot()
# Out:
# <AxesSubplot:>

# %%
df['BsmtFinType1'].value_counts()
# Out:
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64

# %%
pd.crosstab(df['HouseStyle'],df['BsmtFinType1'])
# Out:
# BsmtFinType1  ALQ  BLQ  GLQ  LwQ  Rec  Unf
# HouseStyle
# 1.5Fin         13   18    9   17   25   67
# 1.5Unf          2    1    1    1    0    9
# 1Story        128   93  212   33   78  155
# 2.5Fin          0    0    1    2    0    5
# 2.5Unf          0    0    0    0    4    7
# 2Story         48   30  148   17   23  175
# SFoyer          8    3   23    2    0    0
# SLvl           21    3   24    2    3   12

# %%
sns.heatmap(pd.crosstab(df['HouseStyle'],df['BsmtFinType1']))
# Out:
# <AxesSubplot:xlabel='BsmtFinType1', ylabel='HouseStyle'>

# %%
#Data preparation
## MSSubclass : numerical 20 => 190 ~ 
sns.boxplot(x='MSSubClass', y='log_SalePrice', data=df)
# Out:
# <AxesSubplot:xlabel='MSSubClass', ylabel='log_SalePrice'>

# %%
## MSZoning
sns.boxplot(x='MSZoning', y='log_SalePrice', data=df)
# Out:
# <AxesSubplot:xlabel='MSZoning', ylabel='log_SalePrice'>

# %%
# LotFrontage
sns.scatterplot(x='LotFrontage', y='log_SalePrice', data=df)
# Out:
# <AxesSubplot:xlabel='LotFrontage', ylabel='log_SalePrice'>

# %%
df['log_LotFrontage'] = np.log(df['LotFrontage'])

# %%
sns.scatterplot(x='log_LotFrontage', y='log_SalePrice', data=df)
# Out:
# <AxesSubplot:xlabel='log_LotFrontage', ylabel='log_SalePrice'>

# %%
sns.distplot(df.log_LotFrontage)
# Out:
# <AxesSubplot:xlabel='log_LotFrontage', ylabel='Density'>

# %%
df.loc[df.log_LotFrontage >= 5.5, 'log_LotFrontage_mod'] = 'mod4'
df.loc[df.log_LotFrontage < 5.5, 'log_LotFrontage_mod'] = 'mod3'
df.loc[df.log_LotFrontage < 3.7, 'log_LotFrontage_mod'] = 'mod2'
df.loc[df.log_LotFrontage < 3.2, 'log_LotFrontage_mod'] = 'mod1'

# %%
sns.boxplot(x='log_LotFrontage_mod', y='log_SalePrice', data=df)
# Out:
# <AxesSubplot:xlabel='log_LotFrontage_mod', ylabel='log_SalePrice'>

# %%
sns.scatterplot(x='LotArea', y='log_SalePrice', data=df)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='log_SalePrice'>

# %%
df.loc[df.LotArea >= 50000, 'LotArea_group'] = 'big_area'
df.loc[df.LotArea < 50000, 'LotArea_group'] = 'small_area'

# %%
sns.boxplot(x='LotArea_group', y='log_SalePrice', data=df)
# Out:
# <AxesSubplot:xlabel='LotArea_group', ylabel='log_SalePrice'>

# %%
sns.boxplot(x='OverallCond', y='log_SalePrice', data=df)
# Out:
# <AxesSubplot:xlabel='OverallCond', ylabel='log_SalePrice'>

# %%
df.HouseStyle.isnull().sum()
# Out:
# 0

# %%
sns.boxplot(x='HouseStyle',y='log_SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='HouseStyle', ylabel='log_SalePrice'>

# %%
sns.scatterplot(x='LotArea',y='log_SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='log_SalePrice'>

# %%
sns.clustermap(pd.crosstab(df['HouseStyle'],df['BsmtFinType1']))

# %%
import xgboost as xgb

# %%
def benchmark(x):
    return [12.024]*len(x)

# %%
import xgboost as xgb
def benchmark(x):
    return [12.024]*len(x)

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y, y+0.3993)
# Out:
# 0.15944049000000016

# %%
mean_squared_error(y,benchmark(X))
# Out:
# 0.15945250874753328

# %%
predictors = ['MSSubClass', 'MSZoning', 'log_LotFrontage_mod', 'LotArea_group', 
              'OverallCond']

# %%
X, y = pd.get_dummies(df[predictors]), df['log_SalePrice']

# %%
model =xgb.XGBRegressor()

model.fit(X, y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
y_pred = model.predict(X)

# %%
mean_squared_error(y, y_pred)
# Out:
# 0.07165958385182714

# %%
model.fit(X,y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=100, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %% [raw]
# y_pred=model.predict(x)

# %%
mean_squared_error(y,y_pred)
# Out:
# 0.07165958385182714

# %%
from sklearn.model_selection import cross_val_score

model = xgb.XGBRegressor(n_estimators=500, max_depth=2)
cross_val_score(model, X, y, cv=5)
# Out:
# array([0.48679985, 0.49382326, 0.42412921, 0.41513441, 0.31866262])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=13)

# %%
model = xgb.XGBRegressor(n_estimators=500, max_depth=2)
cv_score = cross_val_score(model, X_train, y_train, cv=5, scoring='neg_mean_squared_error')

# %%
print('{0:5f} ({1:7f})'.format(-cv_score.mean(), cv_score.std()))
# Out:
# 0.092068 (0.015120)

# %%
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=2, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=500, n_jobs=0,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, ...)

# %%
y_pred = model.predict(X_test)

mean_squared_error(y_test, y_pred)
# Out:
# 0.09227815678496917

# %%
mean_squared_error(y_train, model.predict(X_train))
# Out:
# 0.07821565758194356

# %%
np.exp(0.09227815678496917) - 1
# Out:
# 0.0966698258123424

# %%
len(predictors)
# Out:
# 5

# %%
df.groupby('Alley').Id.count()
# Out:
# Alley
# Alley_NA    1369
# Grvl          50
# Pave          41
# Name: Id, dtype: int64

# %%
df.Alley.fillna('Alley_NA',inplace=True)

# %%
sns.boxplot(x='Alley',y='log_SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Alley', ylabel='log_SalePrice'>

# %%
df.groupby('LandContour').Id.count()
# Out:
# LandContour
# Bnk      63
# HLS      50
# Low      36
# Lvl    1311
# Name: Id, dtype: int64

# %%
df.groupby('LotShape').Id.count()
# Out:
# LotShape
# IR1    484
# IR2     41
# IR3     10
# Reg    925
# Name: Id, dtype: int64

# %%
sns.boxplot(x='LotShape',y='log_SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='LotShape', ylabel='log_SalePrice'>

# %%
sns.boxplot(x='LandContour',y='log_SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='LandContour', ylabel='log_SalePrice'>

# %%
sns.boxplot(x='LotConfig',y='log_SalePrice',data=df,hue='LotArea_group')
# Out:
# <AxesSubplot:xlabel='LotConfig', ylabel='log_SalePrice'>

# %%
sns.boxplot(x='Neighborhood',y='log_SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='Neighborhood', ylabel='log_SalePrice'>

# %%
plt.figure(figsize=(18,6))
sns.countplot(x='Neighborhood',data=df)
plt.xticks(rotation=45)
plt.show()

# %%
df['LotShape']=df['LotShape'].replace(['IR1','IR2','IR3'],'IR')

# %%
sns.boxplot(x='BldgType',y='log_SalePrice',data=df)
# Out:
# <AxesSubplot:xlabel='BldgType', ylabel='log_SalePrice'>

# %%
#'Alley', 'LotShape', 'LandContour', 'LotConfig',
      # 'LandSlope', 'Neighborhood', 'Condition1', 'BldgType',
      # 'HouseStyle', 'OverallQual', 'OverallCond'
        #df.groupby('Alley').Id.count()
        #df.Alley.fillna('Alley_NA',inplace=True)
        #sns.boxplot(x='Neighborhood',y='log_SalePrice',data=df
        #df.HouseStyle.isnull().sum()

# %%
predictors = ['MSSubClass', 'MSZoning', 'log_LotFrontage_mod', 'LotArea_group', 
              'OverallCond','Alley', 'LotShape', 'LandContour', 'LotConfig',
       'LandSlope', 'Neighborhood', 'Condition1', 'BldgType',
       'HouseStyle', 'OverallQual', 'OverallCond']

# %%
df.Hou.isnull().sum()

# %%
df.log_LotFrontage_mod.fillna('mod_na',inplace=True)

# %%
from skealrn.impute  import KNNImputer 
imputer=

# %%
sns.regplot(x='LotArea',y='log_SalePrice',data=df.query('LotArea<=25000'))
# Out:
# <AxesSubplot:xlabel='LotArea', ylabel='log_SalePrice'>

# %%
#en chercher y=ax+b
from scipy import stats
x_=df.query('LotFrontage>0 and LotArea<=25000').LotArea
y_=df.query('LotFrontage>0 and LotArea<=25000').LotFrontage
a,b,r_value,p_value,sdterr=stats.linregress(df.Lo)

# %%
a,b

# %%
sns.scatterplot(x='LotArea',y='log_SalePrice',data=df.query('LotArea>25000'))

# %%
df.query('LotArea>25000').LotFrontage.isnull().sum()

# %%
df.query('LotArea>25000').LotFrontage.isnull().median()

# %%
def LotFrontage_imputer(x):
    if x>=25000:
        return 84.5
    else :
        return a*x+b

# %%
df[LotFrantage_imputed]=
df.apply(lambda x:LotFrontage_imputer(x.LotArea) if pd.isna(x.LotArea) else : )

# %%
predictors

# %%
df[predictors]isnull().sum().sum()
